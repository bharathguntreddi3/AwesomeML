# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('example_datasets/dataset1/')
df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df.to_csv('converted_csv', index=False)

# %%
pd.read_excel('example_datasets/dataset_xl.xlsx') #
# Out:
#    Unnamed: 0   a   b   c   d
# 0           0   0   1   2   3
# 1           1   4   5   6   7
# 2           2   8   9  10  11
# 3           3  12  13  14  15

# %%
df.to_excel('converted_xl.xlsx')

# %%
df = pd.read_html('https://en.wikipedia.org/wiki/Minnesota')

# %%
df[0]
# Out:
#                                             Minnesota  \
# 0                                               State
# 1   .mw-parser-output .ib-settlement-cols{text-ali...
# 2   Nickname(s): Land of 10,000 Lakes;North Star S...
# 3   Motto: L'Étoile du Nord (French: The Star of t...
# 4                           Anthem: "Hail! Minnesota"
# 5   Map of the United States with Minnesota highli...
# 6                                             Country
# 7                                    Before statehood
# 8                               Admitted to the Union
# 9                                             Capital
# 10                                       Largest city
# 11                      Largest metro and urban areas
# 12                                         Government
# 13                                         • Governor
# 14                              • Lieutenant Governor
# 15                                        Legislature
# ...

# %% [markdown]
# ## SQLALchemy
# ### The pandas.io.sql module provides a collection of query wrappers to both facilitate data retrieval and to reduce dependency on DB-specific API. Database abstraction is provided by SQLAlchemy if installed.
#
# ### pip install sqlalchemy
# ### from sqlalchemy import create_engine
#
# * read_sql_table(table_name, con[, schema, ...])
#     * Read SQL database table into a DataFrame.
# * read_sql_query(sql, con[, index_col, ...])
#     * Read SQL query into a DataFrame.
# * read_sql(sql, con[, index_col, ...])
#     * Read SQL query or database table into a DataFrame.
# * DataFrame.to_sql(name, con[, flavor, ...])
#     * Write records stored in a DataFrame to a SQL database.
