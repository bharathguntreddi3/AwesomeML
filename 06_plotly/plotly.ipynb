# %%
# Plotly is a library that allows you to create interactive plots and save the images

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from plotly.offline import download_plotlyjs, init_notebook_mode, iplot
import cufflinks as cfk

# %%
init_notebook_mode(connected=True)  # for notebooks connects js to notebook
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.18.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
cfk.go_offline()       # for offline use
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.18.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df1 = pd.DataFrame(np.random.randn(100,4),columns='A B C D'.split())
df1.head()
# Out:
#           A         B         C         D
# 0 -2.012269  0.680834 -0.550532 -0.829925
# 1  1.540730 -1.026838  0.346023 -0.260813
# 2  0.821873  0.195589  0.361942 -0.681027
# 3 -0.709547 -1.909704 -0.590181  0.656572
# 4  0.789150 -1.527486  0.229440  1.356791

# %%
df2 = pd.DataFrame({'Category' : ['A','B','C'], 
                    'values' : [10,20,30]
                    })
df2.head()
# Out:
#   Category  values
# 0        A      10
# 1        B      20
# 2        C      30

# %%
df1.iplot(kind='scatter', x='A', y='B') # scatter
# Out:
# <div>                            <div id="26ca89d3-0fca-4e6e-8963-3dfc05a417a7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
# when we hover on the top right corner we will have some tools and the legend is also interactive

# %%
df2.iplot(kind='bar',x='Category',y='values')   # bar
# Out:
# <div>                            <div id="73cf4803-60c4-41fc-84f5-5369088c8b79" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df[['A','B']].iplot(kind='spread')    #Spread
# Out:
# c:\Users\Hayan\AppData\Local\Programs\Python\Python310\lib\site-packages\cufflinks\plotlytools.py:849: FutureWarning:
#
# The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead.
#
# c:\Users\Hayan\AppData\Local\Programs\Python\Python310\lib\site-packages\cufflinks\plotlytools.py:850: FutureWarning:
#
# The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead.
# <div>                            <div id="08ae9220-7ead-4082-a0a6-5b491f7689ce" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df1.iplot(kind='ratio')    # Ratio
# Out:
# <div>                            <div id="22bd9b7c-2086-45a8-80d9-f57e94394112" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df1.iplot(kind='heatmap')   # heatmap
# Out:
# <div>                            <div id="d5832da1-ff76-418b-8446-c0e353ed6c1e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df3 = pd.DataFrame({'x':[1,2,3,4,5],
                    'y':[10,20,30,20,10],
                    'z':[5,4,3,2,1]
                    })
df3.iplot(kind='surface',colorscale='rdylbu')   # 3d surface
# Out:
# <div>                            <div id="8f1b6b62-0930-4226-ac20-12fa23a0b900" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df1['A'].iplot(kind='hist', bins=25)    #histogram
# Out:
# <div>                            <div id="5875ddd4-bb80-4efc-a038-bd7e9301c625" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df1.iplot(kind='bubble', x = 'A', y = 'B', size='C')
# Out:
# <div>                            <div id="b53f4938-7d31-4ee0-8c7d-ef38c5908e48" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df1.scatter_matrix()    # scatter matrix
# Out:
# <div>                            <div id="d3689e3a-d682-4244-b9f8-3cbb302ebb7a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
# THESE ARE THE BASIC PLOTS THAT ARE DONE PLOTLY AND CUFFLINKS
